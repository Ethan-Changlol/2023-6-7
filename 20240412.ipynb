# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan-Changlol/2023-6-7/blob/main/20240412.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Notes
# <pre>
# #Creating qrcode
# </pre>

# %%
from PIL import Image

# %%
img = Image.open('dog.jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1280>

# %%
img.size
# Out:
# (1920, 1280)

# %%
# !pip install qrcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 5.8 MB/s eta 0:00:00
# ...

# %%
import qrcode
qrcodeimg = qrcode.make('https://www.theflockhouse.com/?gad_source=1&gclid=CjwKCAjwt-OwBhBnEiwAgwzrUlxxPgaSI8HOPG0QseQLJFgPL16ZsMmBuADlrFSjIwEztHDeVuD5IxoC1pkQAvD_BwE')

# %%
qrcodeimg
