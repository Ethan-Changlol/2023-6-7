# %% [markdown]
# <a href="https://colab.research.google.com/github/Ethan-Changlol/2023-6-7/blob/main/20240329.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# use type(xxx) to figure out if it i int, float , bool, or str

# %%
#str
str
<pre>
#str
</pre>

# %% [markdown]
# #math symbols
#
# <pre>
# #math symbols
# </pre>

# %%
3+2
# Out:
# 5

# %%
6/2
# Out:
# 3.0

# %%
3//2
# Out:
# 1

# %%
3==2
# Out:
# False

# %%
3 != 2
# Out:
# True

# %%
x = y = z = c = 1

# %%
y += 1
x -= 1
z *= 1
c /= 1
y
x
z
c
# Out:
# 1.0

# %% [markdown]
# #Importing image
# <pre>
# #Importing image
# </pre>

# %%
from PIL import Image

# %%
img = Image.open('balls.jpeg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>

# %%
img.size
img.mode
img.format
img.convert('L').save("ball.jpeg")

# %%
img.resize?

# %%
img.resize((200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
img2 = img.copy()
img2.thumbnail((1000,1000))
img2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img2.transpose(Image.Transpose.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img2.rotate(45,expand=1,fillcolor="white")
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
r,g,b = img2.split()
Image.merge('RGB',(b,g,r))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
img2.crop((50,0,150,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img3 = img2.crop((50,0,150,100))

# %%
img4 = Image.merge('RGB',(b,g,r))

# %%
img4.paste(img3,(50,0))
img4
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
